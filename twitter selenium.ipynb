# %%
# Scrapping works only for images from AIrbnb http://insideairbnb.com/get-the-data.html excel
import pandas as pd
import numpy as np
import urllib
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import os
import time

#works in mac only and only for airbnb listings url 
#scrapped images from  the slide show for each airbnb listing
options = webdriver.ChromeOptions()
options.binary_location = '/Applications/Google Chrome Canary.app/Contents/MacOS/Google Chrome Canary'
options.add_argument('window-size=800x841')
# options.add_argument('headless')
driver = webdriver.Chrome(chrome_options=options)
#https://twitter.com/search?q=%22YouTube%20HQ%22&src=tren&data_id=tweet%3A981284628614049794
data_url="https://twitter.com/hashtag/happy?src=tren"

# %%
driver.get(data_url)
try:
    for i in range(1,2):
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        #time_last=last.find_element_by_xpath("//small[@class='time']")
        time.sleep(2)

#time complexity in jupyter notebook
#    %timeit s = set(t)
    count=0   
    tweets_cont=driver.find_elements_by_xpath('//*[@id="stream-items-id"]/li')
    tweets_cont_set = set(tweets_cont)
    tweet=[];Account_Name=[];Account_id=[];Account_verified=[];tweet_datetime=[];
    Tweet_image=[];actions=[];
    for t in tweets_cont_set:
        
        try:
            a=t.find_element_by_class_name('js-tweet-text-container');
            b=t.find_element_by_class_name('stream-item-header');
            c=t.find_element_by_class_name('ProfileTweet-actionList');
            d=t.find_element_by_class_name('time').get_attribute('innerHTML');
#             d=t.find_element_by_xpath("//small[@class='time']")
            tweet.append(a.text)
#     tweet_datetime.append(d.split('title="')[1].split(' data-conversation-id')[0])
            tweet_datetime.append(d.split('title="')[1].split(' data-conversation-id')[0])
            user=[];actionList=[];
            user=b.text.split('\n')
            actionList=c.text.split('\n')
            actions.append(actionList)
#             Retweet.append(actionList[3])
#             Like.append(actionList[5])
            if(len(user)==5):
                Account_Name.append(user[0]);
                Account_id.append(user[2]);
                Account_verified.append("Yes")
            else:
                Account_Name.append(user[0]);
                Account_id.append(user[1]);
                Account_verified.append("No")
            count=count+1;
            try:
                e=t.find_element_by_class_name('AdaptiveMediaOuterContainer');
                botLink=e.find_element_by_tag_name('img');
                image=botLink.get_attribute("src")
                Tweet_image.append(image); 
            except:
                Tweet_image.append(" ");
                continue
        except:
            continue
            #print tweet.text
    df_list = pd.DataFrame({'tweet': tweet,
                            'Account Name':Account_Name,
                            'Account Id':Account_id,
                            'Account Verified':Account_verified,
                            'Actions':actions,
                            'Date Time':tweet_datetime,
                            'media':Tweet_image
                            
                            
                })
except NoSuchElementException:
    print data_url + "  is no longer available."
driver.close()

# %%
df_list
# Out:
#           Account Id                          Account Name Account Verified  \
# 0                 😇                          Angel Eyes                 No
# 1   Verified account  Real Marsha Wright| Brand Influencer               No
# 2                51m                           Mr. S سفردن              Yes
# 3        @kellyteong                                   K T               No
# 4                 2h                        sriti my fuggi              Yes
# 5                 4h                                  Carm              Yes
# 6                 2h                       Noelle E Parker              Yes
# 7                 7m                       Andrea McKellar              Yes
# 8                21h                        Haifa AlAngari              Yes
# 9                 5h                        Anthony Ghanem              Yes
# 10         @cellvids                     Cell Phone Videos               No
# 11           @ikemba                     Anthony Onyemauwa               No
# 12                3h                          EVThirdGrade              Yes
# 13                7h                                Malec♡              Yes
# 26  https://pbs.twimg.com/media/DbI6I1CU8AA55sQ.jpg
# 27
# 28  https://pbs.twimg.com/media/DbJiCBlXcAI9VZ6.jpg
# 29  https://pbs.twimg.com/media/DbFN38sXkAE8pXM.jpg
# 30  https://pbs.twimg.com/media/DbFSQ7_UQAAzVVX.jpg
# 31  https://pbs.twimg.com/media/DbJuh04UMAMnho0.jpg
# 32  https://pbs.twimg.com/media/DbGw5u8VAAAPJOB.jpg
# 33  https://pbs.twimg.com/media/DbH9qSWWkAAjrw7.jpg
# 34  https://pbs.twimg.com/media/DbHUoazW0AA9vx2.jpg
# 35
# 36  https://pbs.twimg.com/media/DbCyiqNXUAEr6Gw.jpg
# 37  https://pbs.twimg.com/media/DYt9_RbXkAAq0YF.png
# 38  https://pbs.twimg.com/media/DbIMMhBX4AEz4m5.jpg
# 39
#
#                                                 tweet
# 0   Good morning you amazing people, I woke up fee...
# 1   Just 3 keys that are found on your computer to...
# 2   The happiest people don't have the best ofever...
# 3          Officially an ACCA affiliate  #ACCA #happy
# 4   the magic of love from #Abhigya today #happy  ...
# 5   Honestly I’ve really struggled with loving mys...
# 6   Her milkshake drinking face ♡\n\n#melsdiner #m...
# 7   We have been encouraged to doodle! #missionalv...
# 8       I really can’t believe this is Saudi! #Happy
# 9                          It deserves a tweet #happy
# 10  "𝙉𝙖𝙝, 𝙬𝙚 𝙟𝙪𝙨𝙩 𝙛𝙧𝙞𝙚𝙣𝙙𝙨"  \n\n#f...
# 11  Be happy for this moment. This moment is your ...
# 12  Just a glimpse of what’s going on in room 18 t...
# 13  @ShadowhuntersTV IS ON TOP TEN FOR MOST SOCIAL...
# 14  Happy Mickey’s a friendly, social boy! He was ...
# 15  Some cheerful Haydn for your day\n#concerto #1...
# 16  It's here!  It's here!  The very first #Unicor...
# 17  You have always been my pride, my sunshine Pra...
# 18                             #Happy Thursday All !
# 19  Few lovely shots from a recent shoot. Beautifu...
# 20  Delighted to have won the Best Wine List in th...
# 21  #IPL2018 #IPL \n#RRVKKR \nALMOST FINAL SL TEAM...
# 22  Tag that stupid friend below - follow hipnomem...
# 23  #happy #me #sunshine .. wish I could say this ...
# 24             A #happy day needs an Airedale smile!
# 25  Lovely evening walk to soak up every last ray....
# 26                        #happy Thursday Grobanites
# 27                  #Happy Independence Day Zimbabwe.
# 28  Have just received these from my agent to cele...
# 29  I’m glad to be alive #smiling #happy #goodnigh...
# 30      April 18 2018 kings day  #happy birthdaytome
# 31  Okay Japan a Really TAEKOOKLAND they're playin...
# 32  #WednesdayWisdom \n#happy \nEarly birthday pre...
# 33  It’s our first trip as a group today! @LGBT_BS...
# 34  To my #twitterfriends #Happy #Thursday and dre...
# 35  When a Mad Goan-Bawa meets a Mad Qureshi @Dian...
# 36  #Happy #WinItWednesday Simply #RT and #follow ...
# 37  Time is running out! Enter now for a chance to...
# 38  Happy them... Happy me \n#Blackpink #Jisoo #Je...
# 39  Stop looking for reasons to be unhappy and thi...

# %%
df_list.to_csv("/Users/jaideep/Desktop/error_project/twitter_scrapped.csv", sep=',', encoding='utf-8')
